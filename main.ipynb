# %%
from roboflow import Roboflow
rf = Roboflow(api_key="y1QKJjEjOsG45e3N9r4m")
project = rf.workspace("mark-do").project("toyotachallengef23")
dataset = project.version(6).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.202, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to ToyotaChallengeF23-6 in yolov8:: 100%|██████████| 1907/1907 [00:05<00:00, 354.72it/s]

# %%
from ultralytics import YOLO
import cv2
import torch

torch.cuda.set_device(0)
model = YOLO(r"yolov8n.pt")

# %%
results = model.train(data=r"C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-6\data.yaml", epochs=20,imgsz=640)
# Out:
# Ultralytics YOLOv8.0.202  Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
model(r"C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-5\valid\images", save=True, save_txt=True)
# Out:
# image 1/35 C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-5\valid\images\WIN_20231028_10_13_36_Pro_jpg.rf.b82b6d47b437186b27de14344439e2a5.jpg: 640x640 1 Covered, 4 Holes, 2 Partials, 44.0ms
# image 2/35 C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-5\valid\images\WIN_20231028_10_13_40_Pro_jpg.rf.4a82054704d5d02712ce7957f6156f3b.jpg: 640x640 2 Covereds, 4 Holes, 2 Partials, 24.0ms
# image 3/35 C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-5\valid\images\WIN_20231028_10_13_44_Pro_jpg.rf.1c3a9ef41c7499f11108ed0ddb7e0e10.jpg: 640x640 3 Holes, 1 Partial, 24.0ms
# image 4/35 C:\Users\Humperdink2\Documents\github\ToyotaChallengeF23\ToyotaChallengeF23-5\valid\images\WIN_20231028_10_13_54_Pro_jpg.rf.b0c233037d9c36f717361c6754cf03c0.jpg: 640x640 2 Holes, 1 Partial, 24.3ms
# ...
